# %%
import pandas as pd
import numpy as np
# %matplotlib inline
df = pd.read_csv('Sample_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.memory_usage()
# Out:
# Index          128
# #             6400
# Name          6400
# Type 1        6400
# Type 2        6400
# HP            6400
# Attack        6400
# Defense       6400
# Sp. Atk       6400
# Sp. Def       6400
# Speed         6400
# Generation    6400
# Legendary      800
# dtype: int64

# %%
df = pd.read_csv('Sample_data.csv', dtype = {'#':'int16', 'HP':'int16', 'Attack':'int16', 'Defense':'int16', 'Sp. Atk':'int16', 'Sp. Def':'int16', 'Speed':'int16', 'Generation':'category', 'Type 1':'category', 'Type 2':'category'})
df.memory_usage()
# Out:
# Index          128
# #             1600
# Name          6400
# Type 1        1500
# Type 2        1500
# HP            1600
# Attack        1600
# Defense       1600
# Sp. Atk       1600
# Sp. Def       1600
# Speed         1600
# Generation     848
# Legendary      800
# dtype: int64

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation  Legendary
# 0         65       65     45          1      False
# ...

# %% [markdown]
# ## Reading Data in Pandas

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name','Attack']]
# Out:
#                       Name  Attack
# 0                Bulbasaur      49
# 1                  Ivysaur      62
# 2                 Venusaur      82
# 3    VenusaurMega Venusaur     100
# 4               Charmander      52
# ..                     ...     ...
# 695               Zweilous      85
# 696              Hydreigon     105
# 697               Larvesta      85
# 698              Volcarona      60
# 699               Cobalion      90
#
# [700 rows x 2 columns]

# %%
df[0:10]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed Generation  Legendary  Ratio
# 0       65     45          1      False     94
# ...

# %%
df_new = df.loc[df['Type 1'] == 'Fire']

# %%
df.iloc[40,1]
# Out:
# 'Clefairy'

# %%
df_new.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count   52.000000   52.000000   52.000000   52.000000   52.000000   52.000000
# mean   327.403846   69.903846   84.769231   67.769231   88.980769   72.211538
# std    226.262840   19.404123   28.769275   23.658200   30.042121   22.619908
# min      4.000000   38.000000   30.000000   37.000000   15.000000   40.000000
# 25%    143.500000   58.000000   62.250000   51.000000   70.000000   54.750000
# 50%    289.500000   70.000000   84.500000   64.000000   85.000000   67.500000
# 75%    513.250000   80.000000  101.000000   78.000000  109.000000   85.000000
# max    721.000000  115.000000  160.000000  140.000000  159.000000  154.000000
#
#             Speed
# count   52.000000
# mean    74.442308
# std     25.245783
# min     20.000000
# 25%     60.000000
# 50%     78.500000
# 75%     96.250000
# max    126.000000

# %% [markdown]
# ## Sorting/Describing Data

# %%
df.sort_values('Name', ascending = False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed Generation  Legendary
# ...

# %%
df.sort_values(['Type 1','HP'], ascending = [1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed Generation  Legendary
# 520      116       56     95          4      False
# ...

# %%
df.loc[df['Attack'] > 100]
# Out:
#        #                       Name   Type 1  Type 2   HP  Attack  Defense  \
# 7      6  CharizardMega Charizard X     Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y     Fire  Flying   78     104       78
# 12     9    BlastoiseMega Blastoise    Water     NaN   79     103      120
# 19    15      BeedrillMega Beedrill      Bug  Poison   65     150       40
# 39    34                   Nidoking   Poison  Ground   81     102       77
# ..   ...                        ...      ...     ...  ...     ...      ...
# 793  717                    Yveltal     Dark  Flying  126     131       95
# 796  719        DiancieMega Diancie     Rock   Fairy   50     160      110
# 797  720        HoopaHoopa Confined  Psychic   Ghost   80     110       60
# 798  720         HoopaHoopa Unbound  Psychic    Dark   80     160       60
# 799  721                  Volcanion     Fire   Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation  Legendary
# ...

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df['Ratio'] = df['HP'] + df['Defense']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation  Legendary  Ratio
# 0         65       65     45          1      False     94
# ...

# %%
df = df.drop(['Ratio'], axis = 1)

# %%
cols = list(df.columns)
df_new = df[cols[0:4] +[cols[-1]] + cols[4:11]]

# %%
df_new.head(7)
# Out:
#    #                   Name Type 1  Type 2  Ratio  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison     94  45      49       49
# 1  2                Ivysaur  Grass  Poison    123  60      62       63
# 2  3               Venusaur  Grass  Poison    163  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    203  80     100      123
# 4  4             Charmander   Fire     NaN     82  39      52       43
# 5  5             Charmeleon   Fire     NaN    116  58      64       58
# 6  6              Charizard   Fire  Flying    156  78      84       78
#
#    Sp. Atk  Sp. Def  Speed Generation
# 0       65       65     45          1
# 1       80       80     60          1
# 2      100      100     80          1
# 3      122      120     80          1
# 4       60       50     65          1
# 5       80       65     80          1
# 6      109       85    100          1

# %%
df_new.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  Ratio  HP  Attack  Defense  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost    140  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    140  80     160       60
# 799  721            Volcanion     Fire  Water    200  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation
# 797      150      130     70          6
# 798      170      130     80          6
# 799      130       90     70          6

# %%
df_new = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
df_new.head()
# Out:
#      #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 48  43                 Oddish  Grass  Poison  45      50       55       75
#
#     Sp. Def  Speed Generation  Legendary
# 0        65     45          1      False
# 1        80     60          1      False
# 2       100     80          1      False
# 3       120     80          1      False
# 48       65     30          1      False

# %%
df_new = df_new [['Name','Type 1', 'Type 2', 'HP',]]
df_new
# Out:
#                       Name Type 1  Type 2   HP
# 0                Bulbasaur  Grass  Poison   45
# 1                  Ivysaur  Grass  Poison   60
# 2                 Venusaur  Grass  Poison   80
# 3    VenusaurMega Venusaur  Grass  Poison   80
# 48                  Oddish  Grass  Poison   45
# 49                   Gloom  Grass  Poison   60
# 50               Vileplume  Grass  Poison   75
# 75              Bellsprout  Grass  Poison   50
# 76              Weepinbell  Grass  Poison   65
# 77              Victreebel  Grass  Poison   80
# 344                Roselia  Grass  Poison   50
# 451                  Budew  Grass  Poison   40
# 452               Roserade  Grass  Poison   60
# 651                Foongus  Grass  Poison   69
# 652              Amoonguss  Grass  Poison  114

# %%
df_new = df_new.reset_index()
df_new.head()
# Out:
#    index                   Name Type 1  Type 2  HP
# 0      0              Bulbasaur  Grass  Poison  45
# 1      1                Ivysaur  Grass  Poison  60
# 2      2               Venusaur  Grass  Poison  80
# 3      3  VenusaurMega Venusaur  Grass  Poison  80
# 4     48                 Oddish  Grass  Poison  45

# %%
df_new = df_new.sort_values('HP', ascending = False)
df_new = df_new.reset_index(drop = True)
df_new
# Out:
#     index                   Name Type 1  Type 2   HP
# 0     652              Amoonguss  Grass  Poison  114
# 1       2               Venusaur  Grass  Poison   80
# 2       3  VenusaurMega Venusaur  Grass  Poison   80
# 3      77             Victreebel  Grass  Poison   80
# 4      50              Vileplume  Grass  Poison   75
# 5     651                Foongus  Grass  Poison   69
# 6      76             Weepinbell  Grass  Poison   65
# 7       1                Ivysaur  Grass  Poison   60
# 8      49                  Gloom  Grass  Poison   60
# 9     452               Roserade  Grass  Poison   60
# 10     75             Bellsprout  Grass  Poison   50
# 11    344                Roselia  Grass  Poison   50
# 12      0              Bulbasaur  Grass  Poison   45
# 13     48                 Oddish  Grass  Poison   45
# 14    451                  Budew  Grass  Poison   40

# %%
df_new.rename(columns={'index':'#'})
# Out:
#       #                   Name Type 1  Type 2   HP
# 0   652              Amoonguss  Grass  Poison  114
# 1     2               Venusaur  Grass  Poison   80
# 2     3  VenusaurMega Venusaur  Grass  Poison   80
# 3    77             Victreebel  Grass  Poison   80
# 4    50              Vileplume  Grass  Poison   75
# 5   651                Foongus  Grass  Poison   69
# 6    76             Weepinbell  Grass  Poison   65
# 7     1                Ivysaur  Grass  Poison   60
# 8    49                  Gloom  Grass  Poison   60
# 9   452               Roserade  Grass  Poison   60
# 10   75             Bellsprout  Grass  Poison   50
# 11  344                Roselia  Grass  Poison   50
# 12    0              Bulbasaur  Grass  Poison   45
# 13   48                 Oddish  Grass  Poison   45
# 14  451                  Budew  Grass  Poison   40

# %%
df.loc[df['Type 1'] == 'Water', ['Attack']].mean()
# Out:
# Attack    74.151786
# dtype: float64

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending = False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# ...
